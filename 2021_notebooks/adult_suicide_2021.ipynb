# %%
import pandas as pd
# To install, pip install tabula-py in your env
import tabula

# %%
tabula.convert_into(r"..\resources\2021_data.pdf", r"..\uncleaned_csv\adult_suicide2021.csv", output_format="csv", pages='20', stream = True)

# %%
# Read in csv
adult_access_df = pd.read_csv(r"..\uncleaned_csv\adult_suicide2021.csv")
adult_access_df
adult_access_df = adult_access_df.dropna(how='all')

# %%
# Extract second half of ami_df to make second df to be joined back in
adult_access_df_2 = adult_access_df[["Rank", "State", "%.1", "#.1"]]
adult_access_df_2 = adult_access_df_2.rename(columns={"%.1" : "%", "#.1": "#"})

# %%
# drop seperated columns
adult_access_df = adult_access_df.drop(columns={"Rank", "State", "%.1", "#.1"})

# %%
# Splitup problematic data
adult_access_df['Rank'], adult_access_df['State'] = adult_access_df['Rank State'].str.split(' ', 1).str

adult_access_df = adult_access_df.drop(columns='Rank State')
# Out:
# C:\Users\noaht\AppData\Local\Temp/ipykernel_16452/1540202657.py:2: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   adult_access_df['Rank'], adult_access_df['State'] = adult_access_df['Rank State'].str.split(' ', 1).str

# %%
# Rename and reappend cleaned half of dataframe.
adult_access_df = adult_access_df[['Rank', 'State', '%', '#']]
adult_access_df = adult_access_df.append(adult_access_df_2)

# %%
# Reset index to make cleaning possible
adult_access_df = adult_access_df.reset_index(drop=True)

# %%
# Drop bugged rows
adult_suicide_df = adult_access_df.drop(adult_access_df.index[[26, 27, 28]])

# %%
# Drop null rows
adult_suicide_df = adult_suicide_df.dropna(how='all')

# %%
# Reset index for further cleaning
adult_suicide_df = adult_suicide_df.reset_index(drop=True)

# %%
# Assign proper values
adult_suicide_df.loc[11, "Rank"]=12
adult_suicide_df.loc[11, "State"]='Pennsylvania'
adult_suicide_df.loc[37, "#"] = 29000

# %%
# Add suffix 
adult_suicide_df = adult_suicide_df.add_suffix('_adult_suicide_2021')

# %%
adult_suicide_df = adult_suicide_df.rename(columns={'State_adult_suicide_2021' : 'State'})

# %%
# Out:
#    Rank_adult_suicide_2021                 State  %_adult_suicide_2021  \
# 0                        1            New Jersey                  3.47
# 1                        2              New York                  3.63
# 2                        3                 Texas                  3.66
# 3                        4               Florida                  3.67
# 4                        5              Illinois                  3.87
# 5                        6               Georgia                  4.03
# 6                        7              Maryland                  4.07
# 7                        8            California                  4.10
# 8                        9              Michigan                  4.13
# 9                       10              Virginia                  4.16
# 10                      11  District of Columbia                  4.17
# 11                      12          Pennsylvania                  4.17
# 12                      13          South Dakota                  4.21
# 13                      14            New Mexico                  4.25
# 14                      15              Nebraska                  4.29
# 15                      16               Arizona                  4.43
# 16                      17               Alabama                  4.45
# 17                      18             Tennessee                  4.48
# 18                      19           Connecticut                  4.48
# 19                      20              Oklahoma                  4.53
# 20                      21        North Carolina                  4.57
# 21                      22             Louisiana                  4.57
# 22                      23             Minnesota                  4.59
# 23                      24                Hawaii                  4.59
# 24                      25              Kentucky                  4.65
# 25                      26                Nevada                  4.65
# 26                    27.0          Rhode Island                  4.66
# 27                    28.0              Arkansas                  4.71
# 28                    29.0              Missouri                  4.72
# 29                    30.0                 Maine                  4.81
# 30                    31.0           Mississippi                  4.82
# 31                    32.0                Kansas                  4.82
# 32                    33.0        South Carolina                  4.90
# 33                    34.0         New Hampshire                  4.91
# 34                    35.0         Massachusetts                  4.92
# 35                    36.0               Wyoming                  5.04
# 36                    37.0              Delaware                  5.06
# 37                    38.0          North Dakota                  5.11
# 38                    39.0             Wisconsin                  5.17
# 39                    40.0                  Ohio                  5.18
# 40                    41.0               Montana                  5.21
# 41                    42.0               Vermont                  5.22
# 42                    43.0               Indiana                  5.23
# 43                    44.0         West Virginia                  5.26
# 44                    45.0            Washington                  5.30
# 45                    46.0                Oregon                  5.36
# 46                    47.0                  Iowa                  5.40
# 47                    48.0                 Idaho                  5.45
# 48                    49.0              Colorado                  5.51
# 49                    50.0                Alaska                  5.85
# 50                    51.0                  Utah                  6.47
# 51                     NaN              National                  4.34
#
#    #_adult_suicide_2021
# 0               239,000
# 1               558,000
# 2               756,000
# 3               610,000
# 4               376,000
# 5               314,000
# 6               188,000
# 7             1,232,000
# 8               319,000
# 9               267,000
# 10               23,000
# 11              416,000
# 12               27,000
# 13               67,000
# 14               61,000
# 15              237,000
# 16              165,000
# 17              230,000
# 18              125,000
# 19              132,000
# 20              358,000
# 21              159,000
# 22              195,000
# 23               49,000
# 24              157,000
# 25              107,000
# 26               39,000
# 27              106,000
# 28              219,000
# 29               52,000
# 30              107,000
# 31              103,000
# 32              189,000
# 33               53,000
# 34              268,000
# 35               22,000
# 36               38,000
# 37                29000
# 38              231,000
# 39              461,000
# 40               42,000
# 41               26,000
# 42              262,000
# 43               75,000
# 44              303,000
# 45              175,000
# 46              129,000
# 47               69,000
# 48              237,000
# 49               31,000
# 50              141,000
# 51           10,770,000

# %%
adult_suicide_df.to_csv(r'..\resources\adult_suicide_clean2021.csv')
