# %%
import pandas as pd

# %%
file_path = r"resources\us_mobility_report.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#   country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                  US  United States          NaN          NaN         NaN
# 1                  US  United States          NaN          NaN         NaN
# 2                  US  United States          NaN          NaN         NaN
# 3                  US  United States          NaN          NaN         NaN
# 4                  US  United States          NaN          NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# 0             NaN               NaN  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2021-01-01
# 1             NaN               NaN  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2021-01-02
# 2             NaN               NaN  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2021-01-03
# 3             NaN               NaN  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2021-01-04
# 4             NaN               NaN  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2021-01-05
#
# ...

# %%
df.drop(columns='country_region')
df.sort_values(by=['date'])
# Out:
#        country_region_code country_region sub_region_1       sub_region_2  \
# 0                       US  United States          NaN                NaN
# 581688                  US  United States    Tennessee     Carroll County
# 100212                  US  United States      Georgia    Bleckley County
# 581977                  US  United States    Tennessee      Carter County
# 99923                   US  United States      Georgia        Bibb County
# ...                    ...            ...          ...                ...
# 409144                  US  United States     Nebraska  Red Willow County
# 610913                  US  United States        Texas    Burleson County
# 252608                  US  United States     Kentucky       Henry County
# 609592                  US  United States        Texas    Brazoria County
# 530087                  US  United States       Oregon        Coos County
#
#         metro_area iso_3166_2_code  census_fips_code  \
# ...
