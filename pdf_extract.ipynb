# %%
import pandas as pd
# To install, pip install tabula-py in your env
import tabula

# %%
tabula.convert_into("file.pdf", "output.csv", output_format="csv", pages='28', stream = True)

# %%
ami_df = pd.read_csv("output.csv")
ami_df
# Out:
#     Rank           State      %          #  Rank.1               State.1  \
# 0    1.0      New Jersey  16.19  1,115,000    27.0           Mississippi
# 1    2.0          Hawaii  16.27    173,000    28.0             Louisiana
# 2    3.0           Texas  16.32  3,309,000    29.0         New Hampshire
# 3    4.0        Illinois  16.76  1,627,000    30.0             Tennessee
# 4    5.0        Maryland  16.94    778,000    31.0          Rhode Island
# 5    6.0         Florida  17.54  2,861,000    32.0                Kansas
# 6    7.0        New York  17.61  2,713,000    33.0               Montana
# 7    8.0    South Dakota  17.70    113,000    34.0               Vermont
# 8    9.0      New Mexico  17.73    276,000    35.0                  Ohio
# 9   10.0        Nebraska  17.88    252,000    36.0              Colorado
# 10  11.0    Pennsylvania  17.98  1,786,000    37.0               Alabama
# 11  12.0  North Carolina  18.02  1,387,000    38.0              Oklahoma
# ...
