# %%
# Import dependencies
import pandas as pd
from sqlalchemy import create_engine, Table, MetaData

# %%
# Connect to postgres db
engine = create_engine("postgresql://postgres:piechartspassword@project-vu-database-piecharts.c7rvpt2rehpr.us-east-2.rds.amazonaws.com:5432/project_db")

# %%
# Read table to dataframe
master_df = pd.read_sql_query('select * from "master_test_table"',con=engine)

# %%
master_df.dtypes
# Out:
# State                           object
# Rank_adult_access_2019         float64
# percent_adult_access_2019      float64
# pop_adult_access_2019          float64
# Rank_adult_care_access_2020    float64
#                                 ...
# LOC_Q_2019                      object
# TOT_EMP_2020                    object
# JOBS_1000_2020                  object
# LOC_Q_2020                      object
# id                               int64
# Length: 122, dtype: object

# %%
# Remove commas to allow for changing dtypes
master_df = master_df.replace(',','', regex=True)
master_df.head()
# Out:
#         State  Rank_adult_access_2019  percent_adult_access_2019  \
# 0  New Jersey                    36.0                       57.0
# 1       Texas                    47.0                       62.2
# 2    Maryland                    32.0                       56.4
# 3    Virginia                    21.0                       53.7
# 4     Florida                    45.0                       61.4
#
#    pop_adult_access_2019  Rank_adult_care_access_2020  \
# 0               602000.0                         40.0
# 1              1925000.0                         44.0
# 2               429000.0                         32.0
# 3               684000.0                         25.0
# 4              1643000.0                         37.0
#
#    percent_adult_care_access_2020  pop_adult_care_access_2020  \
# 0                            59.9                    663000.0
# 1                            61.7                   1991000.0
# ...

# %%
# Remove % signs from rows
master_df = master_df.replace('%','', regex=True)

# %%
# Change dtpyes
master_df['pop_sub_dis_2019'] = master_df['pop_sub_dis_2019'].astype('int32')

# %%
# 2 Change dtpyes
master_df['pop_adult_uninsured_2019'] = pd.to_numeric(master_df['pop_adult_uninsured_2019'], errors='coerce')
master_df['pop_adult_ami_2020'] = pd.to_numeric(master_df['pop_adult_ami_2020'], errors='coerce')
master_df['percent_youth_someMH_2020'] = pd.to_numeric(master_df['percent_youth_someMH_2020'], errors='coerce')
master_df['TOT_EMP_2018'] = pd.to_numeric(master_df['TOT_EMP_2018'], errors='coerce')
master_df['JOBS_1000_2018'] = pd.to_numeric(master_df['JOBS_1000_2018'], errors='coerce')
master_df['LOC_Q_2018'] = pd.to_numeric(master_df['LOC_Q_2018'], errors='coerce')
master_df['TOT_EMP_2019'] = pd.to_numeric(master_df['TOT_EMP_2019'], errors='coerce')
master_df['JOBS_1000_2019'] = pd.to_numeric(master_df['JOBS_1000_2019'], errors='coerce')
master_df['LOC_Q_2019'] = pd.to_numeric(master_df['LOC_Q_2019'], errors='coerce')
master_df['TOT_EMP_2020'] = pd.to_numeric(master_df['TOT_EMP_2020'], errors='coerce')
master_df['JOBS_1000_2020'] = pd.to_numeric(master_df['JOBS_1000_2020'], errors='coerce')
master_df['LOC_Q_2020'] = pd.to_numeric(master_df['LOC_Q_2020'], errors='coerce')

# %%
master_df.to_sql(name='cleaned_master_table', if_exists='replace', con=engine, index=False)
