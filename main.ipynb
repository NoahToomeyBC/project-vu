# %%
import pandas as pd
import os

# %%
path = os.getcwd()
path
# Out:
# '/Users/kimberlybraud/vdata/Project VU/project-vu'

# %%
file_path = f"{path}/resources/Indicators_of_Anxiety_or_Depression_Based_on_Reported_Frequency_of_Symptoms_During_Last_7_Days (1).csv"
df = pd.read_csv(file_path)
df.head()

df.drop(columns=['Time Period Label'])
# Out:
#                                               Indicator              Group  \
# 0                       Symptoms of Depressive Disorder  National Estimate
# 1                       Symptoms of Depressive Disorder             By Age
# 2                       Symptoms of Depressive Disorder             By Age
# 3                       Symptoms of Depressive Disorder             By Age
# 4                       Symptoms of Depressive Disorder             By Age
# ...                                                 ...                ...
# 8365  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 8366  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 8367  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 8368  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 8369  Symptoms of Anxiety Disorder or Depressive Dis...           By State
#
# ...

# %%
age_df = df[df["Group"] == "By Age"]
age_df.head()
# Out:
#                          Indicator   Group          State       Subgroup  \
# 1  Symptoms of Depressive Disorder  By Age  United States  18 - 29 years
# 2  Symptoms of Depressive Disorder  By Age  United States  30 - 39 years
# 3  Symptoms of Depressive Disorder  By Age  United States  40 - 49 years
# 4  Symptoms of Depressive Disorder  By Age  United States  50 - 59 years
# 5  Symptoms of Depressive Disorder  By Age  United States  60 - 69 years
#
#   Phase  Time Period     Time Period Label Time Period Start Date  \
# 1     1            1  Apr 23 - May 5, 2020              4/23/2020
# 2     1            1  Apr 23 - May 5, 2020              4/23/2020
# 3     1            1  Apr 23 - May 5, 2020              4/23/2020
# 4     1            1  Apr 23 - May 5, 2020              4/23/2020
# 5     1            1  Apr 23 - May 5, 2020              4/23/2020
#
#   Time Period End Date  Value  Low CI  High CI Confidence Interval  \
# ...

# %%
# Check unique indicator values
df['Indicator'].unique()
# Out:
# array(['Symptoms of Depressive Disorder', 'Symptoms of Anxiety Disorder',
#        'Symptoms of Anxiety Disorder or Depressive Disorder'],
#       dtype=object)

# %%
natl_estimate = df[df["Group"] == "National Estimate"]

natl_estimate.head()
# Out:
#                                              Indicator              Group  \
# 0                      Symptoms of Depressive Disorder  National Estimate
# 70                        Symptoms of Anxiety Disorder  National Estimate
# 140  Symptoms of Anxiety Disorder or Depressive Dis...  National Estimate
# 210                    Symptoms of Depressive Disorder  National Estimate
# 280                       Symptoms of Anxiety Disorder  National Estimate
#
#              State       Subgroup Phase  Time Period     Time Period Label  \
# 0    United States  United States     1            1  Apr 23 - May 5, 2020
# 70   United States  United States     1            1  Apr 23 - May 5, 2020
# 140  United States  United States     1            1  Apr 23 - May 5, 2020
# 210  United States  United States     1            2  May 7 - May 12, 2020
# 280  United States  United States     1            2  May 7 - May 12, 2020
#
# ...

# %%
sex_df = df[df["Group"] == "By Sex"]

# %%
ethnicity_df = df[df["Group"] == "By Race/Hispanic ethnicity"]
ethnicity_df["Quartile Range"].value_counts()
# Out:
# Series([], Name: Quartile Range, dtype: int64)

# %%
education_df = df[df["Group"] == "By Education"]

# %%
state_df = df[df["Group"] == "By State"]

# %%
disability_df = df[df["Group"] == "By Disability status"]

# %%
gender_identity_df = df[df["Group"] == "By Gender identity"]

# %%
sexual_orientation_df = df[df["Group"] == "By Sexual orientation"]

# %%
# Noah T age df cleaning
age_df.head()
# Out:
#                          Indicator   Group          State       Subgroup  \
# 1  Symptoms of Depressive Disorder  By Age  United States  18 - 29 years
# 2  Symptoms of Depressive Disorder  By Age  United States  30 - 39 years
# 3  Symptoms of Depressive Disorder  By Age  United States  40 - 49 years
# 4  Symptoms of Depressive Disorder  By Age  United States  50 - 59 years
# 5  Symptoms of Depressive Disorder  By Age  United States  60 - 69 years
#
#   Phase  Time Period     Time Period Label Time Period Start Date  \
# 1     1            1  Apr 23 - May 5, 2020              4/23/2020
# 2     1            1  Apr 23 - May 5, 2020              4/23/2020
# 3     1            1  Apr 23 - May 5, 2020              4/23/2020
# 4     1            1  Apr 23 - May 5, 2020              4/23/2020
# 5     1            1  Apr 23 - May 5, 2020              4/23/2020
#
#   Time Period End Date  Value  Low CI  High CI Confidence Interval  \
# ...

# %%
# Examines non-null values and Dtypes
age_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882 entries, 1 to 8299
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Indicator               882 non-null    object
#  1   Group                   882 non-null    object
#  2   State                   882 non-null    object
#  3   Subgroup                882 non-null    object
#  4   Phase                   882 non-null    object
#  5   Time Period             882 non-null    int64
#  6   Time Period Label       882 non-null    object
#  7   Time Period Start Date  882 non-null    object
#  8   Time Period End Date    882 non-null    object
#  9   Value                   798 non-null    float64
#  10  Low CI                  798 non-null    float64
#  11  High CI                 798 non-null    float64
#  12  Confidence Interval     798 non-null    object
#  13  Quartile Range          0 non-null      object
# ...

# %%
# Create table with dropped quartile range
age_df_noqr = age_df.drop(columns='Quartile Range')

# %%
# Examines rows with null values to see which  
is_NaN = age_df_noqr.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = age_df_noqr[row_has_NaN]
rows_with_NaN
# Out:
#                                               Indicator   Group  \
# 2521                    Symptoms of Depressive Disorder  By Age
# 2522                    Symptoms of Depressive Disorder  By Age
# 2523                    Symptoms of Depressive Disorder  By Age
# 2524                    Symptoms of Depressive Disorder  By Age
# 2525                    Symptoms of Depressive Disorder  By Age
# ...                                                 ...     ...
# 7338  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
# 7339  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
# 7340  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
# 7341  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
# 7342  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
#
#               State            Subgroup Phase  Time Period  \
# 2521  United States       18 - 29 years    -1            1
# 2522  United States       30 - 39 years    -1            1
# ...

# %%
# Display data
natl_estimate.head()
# Out:
#                                              Indicator              Group  \
# 0                      Symptoms of Depressive Disorder  National Estimate
# 70                        Symptoms of Anxiety Disorder  National Estimate
# 140  Symptoms of Anxiety Disorder or Depressive Dis...  National Estimate
# 210                    Symptoms of Depressive Disorder  National Estimate
# 280                       Symptoms of Anxiety Disorder  National Estimate
#
#              State       Subgroup Phase  Time Period     Time Period Label  \
# 0    United States  United States     1            1  Apr 23 - May 5, 2020
# 70   United States  United States     1            1  Apr 23 - May 5, 2020
# 140  United States  United States     1            1  Apr 23 - May 5, 2020
# 210  United States  United States     1            2  May 7 - May 12, 2020
# 280  United States  United States     1            2  May 7 - May 12, 2020
#
# ...

# %%
# Inspect null values for natl_estimate
natl_estimate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126 entries, 0 to 8292
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Indicator               126 non-null    object
#  1   Group                   126 non-null    object
#  2   State                   126 non-null    object
#  3   Subgroup                126 non-null    object
#  4   Phase                   126 non-null    object
#  5   Time Period             126 non-null    int64
#  6   Time Period Label       126 non-null    object
#  7   Time Period Start Date  126 non-null    object
#  8   Time Period End Date    126 non-null    object
#  9   Value                   114 non-null    float64
#  10  Low CI                  114 non-null    float64
#  11  High CI                 114 non-null    float64
#  12  Confidence Interval     114 non-null    object
#  13  Quartile Range          0 non-null      object
# ...

# %%
# Create table with dropped quartile range
natl_estimate_df_noqr = natl_estimate.drop(columns='Quartile Range')

# %%
# Examines rows with null values to see which  
is_NaN_natl = natl_estimate_df_noqr.isnull()
row_has_NaN_natl = is_NaN_natl.any(axis=1)
rows_with_NaN_natl = natl_estimate_df_noqr[row_has_NaN_natl]
rows_with_NaN_natl
# Out:
#                                               Indicator              Group  \
# 2520                    Symptoms of Depressive Disorder  National Estimate
# 2609                       Symptoms of Anxiety Disorder  National Estimate
# 2698  Symptoms of Anxiety Disorder or Depressive Dis...  National Estimate
# 4467                    Symptoms of Depressive Disorder  National Estimate
# 4556                       Symptoms of Anxiety Disorder  National Estimate
# 4645  Symptoms of Anxiety Disorder or Depressive Dis...  National Estimate
# 5784                    Symptoms of Depressive Disorder  National Estimate
# 5875                       Symptoms of Anxiety Disorder  National Estimate
# 5966  Symptoms of Anxiety Disorder or Depressive Dis...  National Estimate
# 7137                    Symptoms of Depressive Disorder  National Estimate
# 7236                       Symptoms of Anxiety Disorder  National Estimate
# ...

# %%
# Examine ethnicity dataframe

ethnicity_df.head()
# Out:
#                           Indicator                       Group  \
# 10  Symptoms of Depressive Disorder  By Race/Hispanic ethnicity
# 11  Symptoms of Depressive Disorder  By Race/Hispanic ethnicity
# 12  Symptoms of Depressive Disorder  By Race/Hispanic ethnicity
# 13  Symptoms of Depressive Disorder  By Race/Hispanic ethnicity
# 14  Symptoms of Depressive Disorder  By Race/Hispanic ethnicity
#
#             State                                      Subgroup Phase  \
# 10  United States                            Hispanic or Latino     1
# 11  United States               Non-Hispanic White, single race     1
# 12  United States               Non-Hispanic Black, single race     1
# 13  United States               Non-Hispanic Asian, single race     1
# 14  United States  Non-Hispanic, other races and multiple races     1
#
#     Time Period     Time Period Label Time Period Start Date  \
# 10            1  Apr 23 - May 5, 2020              4/23/2020
# ...

# %%
# Check for null values
ethnicity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 630 entries, 10 to 8312
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Indicator               630 non-null    object
#  1   Group                   630 non-null    object
#  2   State                   630 non-null    object
#  3   Subgroup                630 non-null    object
#  4   Phase                   630 non-null    object
#  5   Time Period             630 non-null    int64
#  6   Time Period Label       630 non-null    object
#  7   Time Period Start Date  630 non-null    object
#  8   Time Period End Date    630 non-null    object
#  9   Value                   570 non-null    float64
#  10  Low CI                  570 non-null    float64
#  11  High CI                 570 non-null    float64
#  12  Confidence Interval     570 non-null    object
#  13  Quartile Range          0 non-null      object
# ...
